# %%
import numpy as np
import pandas as pd
import os
from math import sqrt

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):

        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])

        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2

    return sqrt(LB_sum)

# %%
from random import random

# %%
sr1 = np.array([x for x in range(100)])
sr2 = np.array([2*x for x in range(100)])
sr3 = np.array([x**2 for x in range(100)])
sr4 = np.array([(x+5)**2 for x in range(100)])

# %%
LB_Keogh(sr1, sr2, 5)
# Out:
# 488.84046477352916

# %%
from math import sqrt

# %%
def DTWDistance(s1, s2,w):
    DTW={}

    w = max(w, abs(len(s1)-len(s2)))

    for i in range(-1,len(s1)):
        for j in range(-1,len(s2)):
            DTW[(i, j)] = float('inf')
    DTW[(-1, -1)] = 0

    for i in range(len(s1)):
        for j in range(max(0, i-w), min(len(s2), i+w)):
            dist= (s1[i]-s2[j])**2
            DTW[(i, j)] = dist + min(DTW[(i-1, j)],DTW[(i, j-1)], DTW[(i-1, j-1)])

    return sqrt(DTW[len(s1)-1, len(s2)-1])

# %%
DTWDistance(sr1, sr2, 5)
# Out:
# 533.0431502233191

# %%
LB_Keogh(sr1, sr3, 5)
# Out:
# 38272.25120109869

# %%
LB_Keogh(sr1, sr4, 5)
# Out:
# 43608.01704962059

# %%
LB_Keogh(sr3, sr4, 5)
# Out:
# 44.48595283907045

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

def diff_dist(x,y):
    '''
    Computing drivative differences between dx and dy
    Arguments:
        x -- dx from signal 1, numpy array of shape ( 3,  )
        y -- dy from signal 2, numpy array of shape ( 3,  )
    Result:
          -- absolute difference of estimated derivatives of x, y
    '''
    dx = ((x[1] - x[0]) + (x[2]-x[0])/2)/2
    dy = ((y[1] - y[0]) + (y[2]-y[0])/2)/2
    return abs(dx-dy)

def DDTW(signal_1, signal_2):
    '''
    Arguments:
        signal_1 -- first time series, numpy array of shape ( n1,  )
        signal_2 -- second time series, numpy array of shape ( n2,  )
    Results:
        ddtw -- distance matrix, numpy array of shape ( n1 - 2, n2 - 2 )
        ddtw_traceback -- traceback matrix, numpy array of shape ( n1 - 2, n2 - 2 )
    ''' 
    assert signal_1.shape[0] != 0 and signal_2.shape[0] != 0, '''Input signals must be a column vectors,
                                                                Please check the input signal dimension.'''
    assert signal_1.shape[0] >= 3 and signal_2.shape[0] >= 3, '''The length of your signal should be 
                                                                 greater than 3 to implement DDTW.'''
    n_rows = signal_1.shape[0]-2
    n_cols = signal_2.shape[0]-2
    ddtw = np.zeros((n_rows,n_cols))
    ddtw_traceback = np.zeros((n_rows,n_cols))
    ddtw[0,0] = diff_dist(signal_1[0:3], signal_2[0:3])
    for i in range(1, n_rows):
        ddtw[i,0] = ddtw[i-1,0] + diff_dist(signal_1[i-1:i+2], signal_2[0:3])
        ddtw_traceback[i,0] = 1
    for j in range(1, n_cols):
        ddtw[0,j] = ddtw[0,j-1] + diff_dist(signal_1[0:3], signal_2[j-1:j+2])
        ddtw_traceback[0,j] = 2
    for i in range(1, n_rows):
        for j in range(1, n_cols):
            temp = np.array([ddtw[i-1,j-1], ddtw[i-1,j], ddtw[i,j-1]])
            best_idx = np.argmin(temp)
            ddtw[i,j] = diff_dist(signal_1[i-1:i+2], signal_2[j-1:j+2]) + temp[best_idx]
            ddtw_traceback[i,j] = best_idx
    return ddtw, ddtw_traceback

def plot_traceback(ddtw,ddtw_traceback):
    i, j = ddtw.shape
    i -= 1
    j -= 1
    x = [i]
    y = [j]
    while (i != 0 or j != 0):
        if i != 0 and j != 0:
            idx_i = [i-1, i-1, i]
            idx_j = [j-1 ,j, j-1]
            idx = int(ddtw_traceback[i,j])
            i = idx_i[idx]
            j = idx_j[idx]
        elif i == 0 and j != 0:
            j = j-1
        elif i != 0 and j == 0:
            i = i-1
        elif i==1 and j == 1:
            i = 0
            j = 0
        x.append(i)
        y.append(j)
    plt.plot(x, y)
    plt.show()
    return x, y
def plot_aligned_sig(y1, y2, x, y):
    new_x = np.zeros(len(x))
    new_y = np.zeros(len(y))
    for i in range(len(x)):
        new_x[i] = y1[x[i]+1]
        new_y[i] = y2[y[i]+1]
    plt.plot(new_x[::-1])
    plt.plot(new_y[::-1])
    plt.title('signal 1')
    plt.show()
    return new_x[::-1], new_y[::-1]
def plot_raw_signals(signal_1, signal_2, title = 'raw_signals'):
    '''
    Arguments:
        signal_1 -- first time series, numpy array of shape ( n1,  )
        signal_2 -- second time series, numpy array of shape ( n2,  )
    Results:
          Figure 
    ''' 
    plt.plot(signal_1)
    plt.plot(signal_2)
    plt.grid()
    plt.title(title)
    plt.xlabel('time')
    plt.ylabel('value')
    plt.show()

# %%
import numpy as np
import numpy
from collections import defaultdict

import matplotlib
import matplotlib.pyplot as plt

def est_derivatives(sig):
    '''
    Compute derivative differences for a signal.
    '''
    if len(sig) < 3:
        print('The length of your signal should be greater than 3 to implement DDTW.')
        return
    sig = np.array(sig)
    d_sig = ((sig[1:-1] - sig[:-2]) + (sig[2:] - sig[:-2])/2)/2
    return d_sig

def generate_window(len_d_sig1, len_d_sig2, K):
    '''
    Generate reduced search space.
    '''
    for i in range(len_d_sig1):
        lb = max(0, i - K)
        ub = min(i + K, len_d_sig2)
        for j in range(lb, ub):
            yield (i + 1, j + 1)

def fast_ddtw(signal_1, signal_2, K = 10):
    '''
    Arguments:
        signal_1 -- first time series, numpy array of shape ( n1,  )
        signal_2 -- second time series, numpy array of shape ( n2,  )
    Results:
        ddtw -- distance matrix, numpy array of shape ( n1 - 2, n2 - 2 )
        ddtw_traceback -- traceback matrix, numpy array of shape ( n1 - 2, n2 - 2 )
    ''' 
   
    d_sig1 = est_derivatives(signal_1)
    d_sig2 = est_derivatives(signal_2)
    
    len_d_sig1, len_d_sig2 = len(d_sig1), len(d_sig2)
    if K > abs(len_d_sig1 -  len_d_sig2):
        window = generate_window( len_d_sig1, len_d_sig2, K )
    else:
        K = 2*abs(len_d_sig1 -  len_d_sig2)
        window = generate_window( len_d_sig1, len_d_sig2, K)
        print('input K is not a good choice... selected K = ', K, 'instead.')
    
    D = defaultdict(lambda: (float('inf'),))
    D[0, 0] = (0, 0, 0)
    for i, j in window:
        dt = abs(d_sig1[i-1] - d_sig2[j-1])
        D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
                      (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
    path = []
    i, j = len_d_sig1, len_d_sig2
    while not (i == j == 0):
        path.append((i-1, j-1))
        i, j = D[i, j][1], D[i, j][2]
    path.reverse()
    return (D[len_d_sig1, len_d_sig2][0], path)

# %%
def generate_window(len_d_seq1, len_d_seq2, K):
    '''
    Generate reduced search space.
    '''
    
    for i in range(len_d_seq1):
        lb = max(0, i - K)
        ub = min(i + K, len_d_seq2)
        for j in range(lb, ub):
            yield (i + 1, j + 1)

def ddtw_distance(seq1, seq2, K = 10):
    '''
    Computes distance between two sequences using DDTW
    '''
    #computing derivative estimate of each seqnal
    seq1, seq2 = seq = np.array(seq1), np.array(seq2)
    d_seq = lambda s: ((s[1:-1] - s[:-2]) + (s[2:] - s[:-2])/2)/2
    d_seq1, d_seq2 = d_seq(seq1), d_seq(seq2)
    len_d_seq1, len_d_seq2 = len(d_seq1), len(d_seq2)

    #K = max(len(d_seq1), len(d_seq2)) // 10
    
    K = max(K, 2 * abs(len(d_seq1) - len(d_seq2)))
    window = generate_window(len_d_seq1, len_d_seq2, K)

    D = defaultdict(lambda: (float('inf'),))
    D[0, 0] = (0, 0, 0)

    for i, k in window:
        dt = abs(d_seq1[i-1] - d_seq2[k-1])
        case1 = (D[i-1, k][0]+dt, i-1, k)
        case2 = (D[i, k-1][0]+dt, i, k-1)
        case3 = (D[i-1, k-1][0]+dt, i-1, k-1)
        D[i, k] = min(case1, case2, case3, key = lambda a: a[0])

    return D[len_d_seq1, len_d_seq2][0]

# %%
ddtw_distance(sr1, sr3)
# Out:
# 9555.0

# %%
fast_ddtw(sr1, sr3)[0]
# Out:
# 9555.0

# %%
fast_ddtw(sr1, sr4)[0]
# Out:
# 10535.0

# %%
fast_ddtw(sr3, sr2)[0]
# Out:
# 9458.0

# %%
fast_ddtw(sr3, sr4)[0]
# Out:
# 60.0

# %%
relevant_tickers = 'BAC, BCS, BK, BNPP, BX, CS, DBKGN, FMCC, GS, HSBA, ING, JPM, KKR, LEHMQ, MCO, MS, RBS, RY, SOCGEN, UBSN, UTX, WFC, BMWG, DAIGN, FIA, GM, HMC, NISSAN, RENA, TM, VOWG, AAPL, AMZN, BBY, CSCO, EBAY, EC, ERICB, GART, NER, GE, GOOG, HPQ, IBM, INTC, MA, MSFT, NOK, SSNLF, SNE, TVS, YHOO, COST, GPS, HD, JCP, TGT, WMT, AIG, BA, DAL, EAD, FDX, UAL, UPS, XP, BBRY, BP, BRKA, CAT, CEOS, CVX, ISM, JNJ, KO, MCD, PEP, PFE, PG, RDSA, SBUX, XOM, AA, BLT, BMO, RIO, VOD, VZ'.split(', ')

# %%
data_path = r'../../data/ohlc-us/'

# %%
os.listdir(data_path)
# Out:
# ['a.us.txt',
#  'aa.us.txt',
#  'aaap.us.txt',
#  'aaba.us.txt',
#  'aac.us.txt',
#  'aal.us.txt',
#  'aamc.us.txt',
#  'aame.us.txt',
#  'aan.us.txt',
#  'aaoi.us.txt',
#  'aaon.us.txt',
#  'aap.us.txt',
#  'aapl.us.txt',
#  'aat.us.txt',
#  'aau.us.txt',
#  'aav.us.txt',
#  'aaww.us.txt',
#  'aaxn.us.txt',
#  'ab.us.txt',
#  'abac.us.txt',
#  'abax.us.txt',
#  'abb.us.txt',
#  'abbv.us.txt',
#  'abc.us.txt',
#  'abcb.us.txt',
#  'abcd.us.txt',
#  'abco.us.txt',
#  'abdc.us.txt',
#  'abe.us.txt',
#  'abeo.us.txt',
#  'abeow.us.txt',
#  'abev.us.txt',
#  'abg.us.txt',
#  'abil.us.txt',
#  'abio.us.txt',
#  'ablx.us.txt',
#  'abm.us.txt',
#  'abmd.us.txt',
#  'abr.us.txt',
#  'abrn.us.txt',
#  'abr_a.us.txt',
#  'abr_b.us.txt',
#  'abr_c.us.txt',
#  'abt.us.txt',
#  'abtx.us.txt',
#  'abus.us.txt',
#  'abx.us.txt',
#  'aby.us.txt',
#  'ac.us.txt',
#  'acad.us.txt',
#  'acbi.us.txt',
#  'acc.us.txt',
#  'acco.us.txt',
#  'accp.us.txt',
#  'acer.us.txt',
#  'acerw.us.txt',
#  'acet.us.txt',
#  'acfc.us.txt',
#  'acgl.us.txt',
#  'acglo.us.txt',
#  'acglp.us.txt',
#  'ach.us.txt',
#  'achc.us.txt',
#  'achn.us.txt',
#  'achv.us.txt',
#  'acia.us.txt',
#  'aciu.us.txt',
#  'aciw.us.txt',
#  'acls.us.txt',
#  'acm.us.txt',
#  'acmr.us.txt',
#  'acn.us.txt',
#  'acnb.us.txt',
#  'acor.us.txt',
#  'acp.us.txt',
#  'acre.us.txt',
#  'acrs.us.txt',
#  'acrx.us.txt',
#  'acsf.us.txt',
#  'acsi.us.txt',
#  'acst.us.txt',
#  'acta.us.txt',
#  'actg.us.txt',
#  'acu.us.txt',
#  'acv.us.txt',
#  'acxm.us.txt',
#  'acy.us.txt',
#  'adap.us.txt',
#  'adbe.us.txt',
#  'adc.us.txt',
#  'ades.us.txt',
#  'adhd.us.txt',
#  'adi.us.txt',
#  'adm.us.txt',
#  'adma.us.txt',
#  'admp.us.txt',
#  'adms.us.txt',
#  'adnt.us.txt',
#  'adom.us.txt',
#  'adp.us.txt',
#  'adro.us.txt',
#  'ads.us.txt',
#  'adsk.us.txt',
#  'adsw.us.txt',
#  'adtn.us.txt',
#  'adus.us.txt',
#  'advm.us.txt',
#  'adx.us.txt',
#  'adxs.us.txt',
#  'adxsw.us.txt',
#  'ae.us.txt',
#  'aeb.us.txt',
#  'aed.us.txt',
#  'aee.us.txt',
#  'aeg.us.txt',
#  'aegn.us.txt',
#  'aeh.us.txt',
#  'aehr.us.txt',
#  'aeis.us.txt',
#  'aek.us.txt',
#  'ael.us.txt',
#  'aem.us.txt',
#  'aemd.us.txt',
#  'aeo.us.txt',
#  'aep.us.txt',
#  'aer.us.txt',
#  'aeri.us.txt',
#  'aes.us.txt',
#  'aet.us.txt',
#  'aeti.us.txt',
#  'aeua.us.txt',
#  'aey.us.txt',
#  'aezs.us.txt',
#  'afam.us.txt',
#  'afb.us.txt',
#  'afc.us.txt',
#  'afg.us.txt',
#  'afge.us.txt',
#  'afgh.us.txt',
#  'afh.us.txt',
#  'afhbl.us.txt',
#  'afi.us.txt',
#  'afl.us.txt',
#  'afmd.us.txt',
#  'afsd.us.txt',
#  'afsi.us.txt',
#  'afsi_a.us.txt',
#  'afsi_b.us.txt',
#  'afsi_c.us.txt',
#  'afsi_d.us.txt',
#  'afsi_e.us.txt',
#  'afsi_f.us.txt',
#  'afss.us.txt',
#  'afst.us.txt',
#  'aft.us.txt',
#  'afty.us.txt',
#  'ag.us.txt',
#  'agc.us.txt',
#  'agco.us.txt',
#  'agd.us.txt',
#  'agen.us.txt',
#  'agfs.us.txt',
#  'agfsw.us.txt',
#  'agge.us.txt',
#  'aggp.us.txt',
#  'aggy.us.txt',
#  'agi.us.txt',
#  'agii.us.txt',
#  'agiil.us.txt',
#  'agio.us.txt',
#  'agle.us.txt',
#  'agm-a.us.txt',
#  'agm.us.txt',
#  'agm_a.us.txt',
#  'agm_b.us.txt',
#  'agm_c.us.txt',
#  'agn.us.txt',
#  'agnc.us.txt',
#  'agncb.us.txt',
#  'agncn.us.txt',
#  'agn_a.us.txt',
#  'ago.us.txt',
#  'ago_b.us.txt',
#  'ago_e.us.txt',
#  'ago_f.us.txt',
#  'agr.us.txt',
#  'agro.us.txt',
#  'agrx.us.txt',
#  'agt.us.txt',
#  'agtc.us.txt',
#  'agu.us.txt',
#  'agx.us.txt',
#  'agys.us.txt',
#  'ahc.us.txt',
#  'ahgp.us.txt',
#  'ahh.us.txt',
#  'ahl.us.txt',
#  'ahl_c.us.txt',
#  'ahl_d.us.txt',
#  'ahp.us.txt',
#  'ahpa.us.txt',
#  'ahpau.us.txt',
#  'ahpaw.us.txt',
#  'ahpi.us.txt',
#  'ahp_b.us.txt',
#  'aht.us.txt',
#  'aht_d.us.txt',
#  'aht_f.us.txt',
#  'aht_g.us.txt',
#  'aht_h.us.txt',
#  'ai.us.txt',
#  'aib-cl.us.txt',
#  'aic.us.txt',
#  'aieq.us.txt',
#  'aif.us.txt',
#  'aig-ws.us.txt',
#  'aig.us.txt',
#  'aimc.us.txt',
#  'aimt.us.txt',
#  'ain.us.txt',
#  'ainc.us.txt',
#  'ainv.us.txt',
#  'air.us.txt',
#  'airg.us.txt',
#  'airi.us.txt',
#  'airt.us.txt',
#  'ait.us.txt',
#  'aiv.us.txt',
#  'aiv_a.us.txt',
#  'aiw.us.txt',
#  'aiy.us.txt',
#  'aiz.us.txt',
#  'ai_b.us.txt',
#  'ajg.us.txt',
#  'ajrd.us.txt',
#  'ajx.us.txt',
#  'ajxa.us.txt',
#  'akam.us.txt',
#  'akao.us.txt',
#  'akba.us.txt',
#  'akca.us.txt',
#  'aker.us.txt',
#  'akg.us.txt',
#  'ako-a.us.txt',
#  'ako-b.us.txt',
#  'akp.us.txt',
#  'akr.us.txt',
#  'akrx.us.txt',
#  'aks.us.txt',
#  'akts.us.txt',
#  'aktx.us.txt',
#  'al.us.txt',
#  'alb.us.txt',
#  'albo.us.txt',
#  'alco.us.txt',
#  'aldr.us.txt',
#  'aldw.us.txt',
#  'aldx.us.txt',
#  'ale.us.txt',
#  'alex.us.txt',
#  'alfi.us.txt',
#  'alg.us.txt',
#  'algn.us.txt',
#  'algt.us.txt',
#  'alim.us.txt',
#  'aljj.us.txt',
#  'alk.us.txt',
#  'alks.us.txt',
#  'all.us.txt',
#  'alle.us.txt',
#  'allt.us.txt',
#  'ally.us.txt',
#  'ally_a.us.txt',
#  'all_a.us.txt',
#  'all_b.us.txt',
#  'all_c.us.txt',
#  'all_d.us.txt',
#  'all_e.us.txt',
#  'all_f.us.txt',
#  'aln.us.txt',
#  'alna.us.txt',
#  'alny.us.txt',
#  'alo.us.txt',
#  'alog.us.txt',
#  'alot.us.txt',
#  'alpn.us.txt',
#  'alp_o-cl.us.txt',
#  'alp_q.us.txt',
#  'alqa.us.txt',
#  'alrm.us.txt',
#  'alrn.us.txt',
#  'alsk.us.txt',
#  'alsn.us.txt',
#  'alt.us.txt',
#  'altr.us.txt',
#  'alty.us.txt',
#  'alv.us.txt',
#  'alx.us.txt',
#  'alxn.us.txt',
#  'am.us.txt',
#  'amag.us.txt',
#  'amat.us.txt',
#  'amba.us.txt',
#  'ambc.us.txt',
#  'ambcw.us.txt',
#  'ambr.us.txt',
#  'amc.us.txt',
#  'amca.us.txt',
#  'amcn.us.txt',
#  'amcx.us.txt',
#  'amd.us.txt',
#  'amda.us.txt',
#  'ame.us.txt',
#  'amed.us.txt',
#  'amfw.us.txt',
#  'amg.us.txt',
#  'amgn.us.txt',
#  'amgp.us.txt',
#  'amh.us.txt',
#  'amh_c.us.txt',
#  'amh_d.us.txt',
#  'amh_e.us.txt',
#  'amh_f.us.txt',
#  'amh_g.us.txt',
#  'amid.us.txt',
#  'amkr.us.txt',
#  'amlx.us.txt',
#  'amma.us.txt',
#  'amn.us.txt',
#  'amnb.us.txt',
#  'amot.us.txt',
#  'amov.us.txt',
#  'amp.us.txt',
#  'ampe.us.txt',
#  'amph.us.txt',
#  'amrb.us.txt',
#  'amrc.us.txt',
#  'amrh.us.txt',
#  'amrhw.us.txt',
#  'amrk.us.txt',
#  'amrn.us.txt',
#  'amrs.us.txt',
#  'ams.us.txt',
#  'amsc.us.txt',
#  'amsf.us.txt',
#  'amswa.us.txt',
#  'amt.us.txt',
#  'amtd.us.txt',
#  'amtx.us.txt',
#  'amt_b.us.txt',
#  'amwd.us.txt',
#  'amx.us.txt',
#  'amza.us.txt',
#  'amzn.us.txt',
#  'an.us.txt',
#  'anab.us.txt',
#  'anat.us.txt',
#  'ancb.us.txt',
#  'ancx.us.txt',
#  'anda.us.txt',
#  'andar.us.txt',
#  'andau.us.txt',
#  'andaw.us.txt',
#  'ande.us.txt',
#  'andv.us.txt',
#  'andx.us.txt',
#  'anet.us.txt',
#  'anf.us.txt',
#  'anfi.us.txt',
#  'angi.us.txt',
#  'ango.us.txt',
#  'anh.us.txt',
#  'anh_a.us.txt',
#  'anh_b.us.txt',
#  'anh_c.us.txt',
#  'anik.us.txt',
#  'anip.us.txt',
#  'anss.us.txt',
#  'anth.us.txt',
#  'antm.us.txt',
#  'antx.us.txt',
#  'anw.us.txt',
#  'any.us.txt',
#  'aobc.us.txt',
#  'aod.us.txt',
#  'aoi.us.txt',
#  'aon.us.txt',
#  'aos.us.txt',
#  'aosl.us.txt',
#  'aoxg.us.txt',
#  'ap.us.txt',
#  'apa.us.txt',
#  'apam.us.txt',
#  'apb.us.txt',
#  'apc.us.txt',
#  'apd.us.txt',
#  'apdn.us.txt',
#  'apdnw.us.txt',
#  'apei.us.txt',
#  'apen.us.txt',
#  'apf.us.txt',
#  'aph.us.txt',
#  'aphb.us.txt',
#  'aple.us.txt',
#  'aplp.us.txt',
#  'apls.us.txt',
#  'apo.us.txt',
#  'apog.us.txt',
#  'apop.us.txt',
#  'apopw.us.txt',
#  'apo_a.us.txt',
#  'appf.us.txt',
#  'appn.us.txt',
#  'apps.us.txt',
#  'apri.us.txt',
#  'aprn.us.txt',
#  'apt.us.txt',
#  'apti.us.txt',
#  'apto.us.txt',
#  'apts.us.txt',
#  'apu.us.txt',
#  'apvo.us.txt',
#  'apwc.us.txt',
#  'aq.us.txt',
#  'aqb.us.txt',
#  'aqms.us.txt',
#  'aqn.us.txt',
#  'aqua.us.txt',
#  'aqxp.us.txt',
#  'ar.us.txt',
#  'ara.us.txt',
#  'aray.us.txt',
#  'arc.us.txt',
#  'arcb.us.txt',
#  'arcc.us.txt',
#  'arch.us.txt',
#  'arci.us.txt',
#  'arcm.us.txt',
#  'arco.us.txt',
#  'arcw.us.txt',
#  'arcx.us.txt',
#  'ard.us.txt',
#  'ardc.us.txt',
#  'ardm.us.txt',
#  'ardx.us.txt',
#  'are.us.txt',
#  'ares.us.txt',
#  'ares_a.us.txt',
#  'arex.us.txt',
#  'are_d.us.txt',
#  'args.us.txt',
#  'argx.us.txt',
#  'arh_c.us.txt',
#  'ari.us.txt',
#  'arii.us.txt',
#  'ari_c.us.txt',
#  'arkg.us.txt',
#  'arkk.us.txt',
#  'arkq.us.txt',
#  'arkr.us.txt',
#  'arkw.us.txt',
#  'arl.us.txt',
#  'arlp.us.txt',
#  'arlz.us.txt',
#  'armk.us.txt',
#  'arna.us.txt',
#  'arnc.us.txt',
#  'arnc_.us.txt',
#  'arnc_b.us.txt',
#  'aroc.us.txt',
#  'arow.us.txt',
#  'arql.us.txt',
#  'arr.us.txt',
#  'arrs.us.txt',
#  'arry.us.txt',
#  'arr_a.us.txt',
#  'arr_b.us.txt',
#  'artna.us.txt',
#  'artw.us.txt',
#  'artx.us.txt',
#  'arw.us.txt',
#  'arwr.us.txt',
#  'asa.us.txt',
#  'asb-ws.us.txt',
#  'asb.us.txt',
#  'asb_c.us.txt',
#  'asb_d.us.txt',
#  'asc.us.txt',
#  'ascma.us.txt',
#  'aset.us.txt',
#  'asfi.us.txt',
#  'asg.us.txt',
#  'asgn.us.txt',
#  'ash.us.txt',
#  'ashx.us.txt',
#  'asix.us.txt',
#  'asm.us.txt',
#  'asmb.us.txt',
#  'asml.us.txt',
#  'asna.us.txt',
#  'asnd.us.txt',
#  'asns.us.txt',
#  'aspn.us.txt',
#  'asps.us.txt',
#  'aspu.us.txt',
#  'asr.us.txt',
#  'asrv.us.txt',
#  'asrvp.us.txt',
#  'ast.us.txt',
#  'astc.us.txt',
#  'aste.us.txt',
#  'asur.us.txt',
#  'asv.us.txt',
#  'asx.us.txt',
#  'asys.us.txt',
#  'at.us.txt',
#  'atac.us.txt',
#  'atacr.us.txt',
#  'atacu.us.txt',
#  'atai.us.txt',
#  'atax.us.txt',
#  'atec.us.txt',
#  'aten.us.txt',
#  'atge.us.txt',
#  'ath.us.txt',
#  'athm.us.txt',
#  'athn.us.txt',
#  'athx.us.txt',
#  'ati.us.txt',
#  'atkr.us.txt',
#  'atlc.us.txt',
#  'atlo.us.txt',
#  'atni.us.txt',
#  'atnm.us.txt',
#  'atnx.us.txt',
#  'ato.us.txt',
#  'atom.us.txt',
#  'atos.us.txt',
#  'atr.us.txt',
#  'atra.us.txt',
#  'atrc.us.txt',
#  'atri.us.txt',
#  'atro.us.txt',
#  'atrs.us.txt',
#  'atsg.us.txt',
#  'atto.us.txt',
#  'attu.us.txt',
#  'atu.us.txt',
#  'atus.us.txt',
#  'atv.us.txt',
#  'atvi.us.txt',
#  'atxi.us.txt',
#  'au.us.txt',
#  'aubn.us.txt',
#  'audc.us.txt',
#  'aug.us.txt',
#  'aumn.us.txt',
#  'auo.us.txt',
#  'auph.us.txt',
#  'auto.us.txt',
#  'auy.us.txt',
#  'ava.us.txt',
#  'aval.us.txt',
#  'avav.us.txt',
#  'avb.us.txt',
#  'avd.us.txt',
#  'avdl.us.txt',
#  'aveo.us.txt',
#  'avgo.us.txt',
#  'avgr.us.txt',
#  'avh.us.txt',
#  'avhi.us.txt',
#  'avid.us.txt',
#  'avir.us.txt',
#  'avk.us.txt',
#  'avnw.us.txt',
#  'avp.us.txt',
#  'avt.us.txt',
#  'avx.us.txt',
#  'avxl.us.txt',
#  'avxs.us.txt',
#  'avy.us.txt',
#  'awf.us.txt',
#  'awi.us.txt',
#  'awk.us.txt',
#  'awp.us.txt',
#  'awr.us.txt',
#  'awre.us.txt',
#  'awx.us.txt',
#  'axas.us.txt',
#  'axdx.us.txt',
#  'axe.us.txt',
#  'axgn.us.txt',
#  'axl.us.txt',
#  'axon.us.txt',
#  'axp.us.txt',
#  'axr.us.txt',
#  'axs.us.txt',
#  'axsm.us.txt',
#  'axs_d.us.txt',
#  'axs_e.us.txt',
#  'axta.us.txt',
#  'axti.us.txt',
#  'axu.us.txt',
#  'ayi.us.txt',
#  'ayr.us.txt',
#  'aytu.us.txt',
#  'ayx.us.txt',
#  'azn.us.txt',
#  'azo.us.txt',
#  'azpn.us.txt',
#  'azre.us.txt',
#  'azrx.us.txt',
#  'azul.us.txt',
#  'azz.us.txt',
#  'b.us.txt',
#  'ba.us.txt',
#  'baa.us.txt',
#  'baba.us.txt',
#  'baby.us.txt',
#  'bac-ws-a.us.txt',
#  'bac-ws-b.us.txt',
#  'bac.us.txt',
#  'bac_a.us.txt',
#  'bac_c.us.txt',
#  'bac_d.us.txt',
#  'bac_e.us.txt',
#  'bac_i.us.txt',
#  'bac_l.us.txt',
#  'bac_w.us.txt',
#  'bac_y.us.txt',
#  'baf.us.txt',
#  'bah.us.txt',
#  'bak.us.txt',
#  'bam.us.txt',
#  'banc.us.txt',
#  'banc_c.us.txt',
#  'banc_d.us.txt',
#  'banc_e.us.txt',
#  'band.us.txt',
#  'banf.us.txt',
#  'banfp.us.txt',
#  'banr.us.txt',
#  'banx.us.txt',
#  'bap.us.txt',
#  'bar.us.txt',
#  'bas.us.txt',
#  'basi.us.txt',
#  'batra.us.txt',
#  'batrk.us.txt',
#  'bax.us.txt',
#  'bb.us.txt',
#  'bbby.us.txt',
#  'bbc.us.txt',
#  'bbd.us.txt',
#  'bbdo.us.txt',
#  'bbf.us.txt',
#  'bbg.us.txt',
#  'bbgi.us.txt',
#  'bbk.us.txt',
#  'bbl.us.txt',
#  'bbn.us.txt',
#  'bbox.us.txt',
#  'bbrg.us.txt',
#  'bbrx.us.txt',
#  'bbsi.us.txt',
#  'bbt.us.txt',
#  'bbt_d.us.txt',
#  'bbt_e.us.txt',
#  'bbt_f.us.txt',
#  'bbt_g.us.txt',
#  'bbt_h.us.txt',
#  'bbu.us.txt',
#  'bbva.us.txt',
#  'bbw.us.txt',
#  'bbx.us.txt',
#  'bby.us.txt',
#  'bc.us.txt',
#  'bcac.us.txt',
#  'bcacr.us.txt',
#  'bcacu.us.txt',
#  'bcacw.us.txt',
#  'bcbp.us.txt',
#  'bcc.us.txt',
#  'bcd.us.txt',
#  'bce.us.txt',
#  'bcei.us.txt',
#  'bch.us.txt',
#  'bci.us.txt',
#  'bcli.us.txt',
#  'bco.us.txt',
#  'bcom.us.txt',
#  'bcor.us.txt',
#  'bcov.us.txt',
#  'bcpc.us.txt',
#  'bcr.us.txt',
#  'bcrh.us.txt',
#  'bcrx.us.txt',
#  'bcs.us.txt',
#  'bcs_d.us.txt',
#  'bctf.us.txt',
#  'bcv.us.txt',
#  'bcv_a.us.txt',
#  'bcx.us.txt',
#  'bdc.us.txt',
#  'bdcz.us.txt',
#  'bdc_b.us.txt',
#  'bdge.us.txt',
#  'bdj.us.txt',
#  'bdl.us.txt',
#  'bdn.us.txt',
#  'bdr.us.txt',
#  'bdsi.us.txt',
#  'bdx.us.txt',
#  'bdxa.us.txt',
#  'beat.us.txt',
#  'bebe.us.txt',
#  'becn.us.txt',
#  'bedu.us.txt',
#  'bef.us.txt',
#  'bel.us.txt',
#  'belfa.us.txt',
#  'belfb.us.txt',
#  'bemo.us.txt',
#  'ben.us.txt',
#  'bep.us.txt',
#  'bern.us.txt',
#  'bery.us.txt',
#  'betr.us.txt',
#  'bf-a.us.txt',
#  'bf-b.us.txt',
#  'bfam.us.txt',
#  'bfin.us.txt',
#  'bfit.us.txt',
#  'bfk.us.txt',
#  'bfo.us.txt',
#  'bfr.us.txt',
#  'bfs.us.txt',
#  'bfs_c.us.txt',
#  'bfy.us.txt',
#  'bfz.us.txt',
#  'bg.us.txt',
#  'bgb.us.txt',
#  'bgc.us.txt',
#  'bgca.us.txt',
#  'bgcp.us.txt',
#  'bgfv.us.txt',
#  'bgg.us.txt',
#  'bgh.us.txt',
#  'bgi.us.txt',
#  'bgio.us.txt',
#  'bgne.us.txt',
#  'bgr.us.txt',
#  'bgs.us.txt',
#  'bgsf.us.txt',
#  'bgt.us.txt',
#  'bgx.us.txt',
#  'bgy.us.txt',
#  'bh.us.txt',
#  'bhac.us.txt',
#  'bhacr.us.txt',
#  'bhacu.us.txt',
#  'bhacw.us.txt',
#  'bhb.us.txt',
#  'bhbk.us.txt',
#  'bhe.us.txt',
#  'bhf.us.txt',
#  'bhge.us.txt',
#  'bhk.us.txt',
#  'bhlb.us.txt',
#  'bhp.us.txt',
#  'bhv.us.txt',
#  'bhvn.us.txt',
#  'bibl.us.txt',
#  'bid.us.txt',
#  'bidu.us.txt',
#  'bif.us.txt',
#  'big.us.txt',
#  'biib.us.txt',
#  'bio-b.us.txt',
#  'bio.us.txt',
#  'bioa.us.txt',
#  'bioc.us.txt',
#  'biol.us.txt',
#  'bios.us.txt',
#  'bip.us.txt',
#  'bit.us.txt',
#  'bita.us.txt',
#  'bivv.us.txt',
#  'bjri.us.txt',
#  'bjz.us.txt',
#  'bk.us.txt',
#  'bkcc.us.txt',
#  'bkd.us.txt',
#  'bke.us.txt',
#  'bkep.us.txt',
#  'bkepp.us.txt',
#  'bkh.us.txt',
#  'bkhu.us.txt',
#  'bki.us.txt',
#  'bkj.us.txt',
#  'bkk.us.txt',
#  'bkmu.us.txt',
#  'bkn.us.txt',
#  'bks.us.txt',
#  'bksc.us.txt',
#  'bkt.us.txt',
#  'bku.us.txt',
#  'bkyi.us.txt',
#  'bk_c.us.txt',
#  'bl.us.txt',
#  'blbd.us.txt',
#  'blcm.us.txt',
#  'bld.us.txt',
#  'bldp.us.txt',
#  'bldr.us.txt',
#  'ble.us.txt',
#  'bles.us.txt',
#  'blfs.us.txt',
#  'blh.us.txt',
#  'blhy.us.txt',
#  'blin.us.txt',
#  'blj.us.txt',
#  'blk.us.txt',
#  'blkb.us.txt',
#  'bll.us.txt',
#  'blmn.us.txt',
#  'blmt.us.txt',
#  'blph.us.txt',
#  'blrx.us.txt',
#  'blue.us.txt',
#  'blvd.us.txt',
#  'blvdu.us.txt',
#  'blvdw.us.txt',
#  'blw.us.txt',
#  'blx.us.txt',
#  'bma.us.txt',
#  'bmch.us.txt',
#  'bme.us.txt',
#  'bmi.us.txt',
#  'bmla.us.txt',
#  'bmlp.us.txt',
#  'bml_g.us.txt',
#  'bml_h.us.txt',
#  'bml_i.us.txt',
#  'bml_j.us.txt',
#  'bml_l.us.txt',
#  'bmo.us.txt',
#  'bmra.us.txt',
#  'bmrc.us.txt',
#  'bmrn.us.txt',
#  'bms.us.txt',
#  'bmtc.us.txt',
#  'bmy.us.txt',
#  'bncl.us.txt',
#  'bndc.us.txt',
#  'bned.us.txt',
#  'bnft.us.txt',
#  'bnj.us.txt',
#  'bns.us.txt',
#  'bnso.us.txt',
#  'bntc.us.txt',
#  'bntcw.us.txt',
#  'bny.us.txt',
#  'bobe.us.txt',
#  'boch.us.txt',
#  'boe.us.txt',
#  'bofi.us.txt',
#  'bofil.us.txt',
#  'boh.us.txt',
#  'boja.us.txt',
#  'bokf.us.txt',
#  'bokfl.us.txt',
#  'bold.us.txt',
#  'bolt.us.txt',
#  'bomn.us.txt',
#  'bont.us.txt',
#  'boom.us.txt',
#  'boot.us.txt',
#  'born.us.txt',
#  'bosc.us.txt',
#  'boss.us.txt',
#  'botj.us.txt',
#  'botz.us.txt',
#  'box.us.txt',
#  'boxl.us.txt',
#  'bp.us.txt',
#  'bpfh.us.txt',
#  'bpfhp.us.txt',
#  'bpfhw.us.txt',
#  'bpi.us.txt',
#  'bpk.us.txt',
#  'bpl.us.txt',
#  'bpmc.us.txt',
#  'bpmp.us.txt',
#  'bpmx.us.txt',
#  'bpop.us.txt',
#  'bpopm.us.txt',
#  'bpopn.us.txt',
#  'bprn.us.txt',
#  'bpt.us.txt',
#  'bpth.us.txt',
#  'bpy.us.txt',
#  'bqh.us.txt',
#  'br.us.txt',
#  'brac.us.txt',
#  'bracr.us.txt',
#  'bracu.us.txt',
#  'bracw.us.txt',
#  'brc.us.txt',
#  'brcd.us.txt',
#  'brew.us.txt',
#  'brfs.us.txt',
#  'brg.us.txt',
#  'brgl.us.txt',
#  'brg_a.us.txt',
#  'brg_c.us.txt',
#  'brg_d.us.txt',
#  'brid.us.txt',
#  'brk-a.us.txt',
#  'brk-b.us.txt',
#  'brkl.us.txt',
#  'brkr.us.txt',
#  'brks.us.txt',
#  'brn.us.txt',
#  'bro.us.txt',
#  'brqs.us.txt',
#  'brqsw.us.txt',
#  'brs.us.txt',
#  'brss.us.txt',
#  'brt.us.txt',
#  'brx.us.txt',
#  'bsac.us.txt',
#  'bsbr.us.txt',
#  'bscp.us.txt',
#  'bscq.us.txt',
#  'bscr.us.txt',
#  'bsd.us.txt',
#  'bse.us.txt',
#  'bset.us.txt',
#  'bsf.us.txt',
#  'bsft.us.txt',
#  'bsjn.us.txt',
#  'bsjo.us.txt',
#  'bsjp.us.txt',
#  'bsl.us.txt',
#  'bsm.us.txt',
#  'bsmx.us.txt',
#  'bspm.us.txt',
#  'bsqr.us.txt',
#  'bsrr.us.txt',
#  'bst.us.txt',
#  'bstc.us.txt',
#  'bsti.us.txt',
#  'bswn.us.txt',
#  'bsx.us.txt',
#  'bt.us.txt',
#  'bta.us.txt',
#  'bte.us.txt',
#  'btec.us.txt',
#  'btg.us.txt',
#  'bti.us.txt',
#  'btn.us.txt',
#  'bto.us.txt',
#  'btt.us.txt',
#  'btu.us.txt',
#  'btu_.us.txt',
#  'btx-ws.us.txt',
#  'btx.us.txt',
#  'btz.us.txt',
#  'bud.us.txt',
#  'buff.us.txt',
#  'bui.us.txt',
#  'bur.us.txt',
#  'burl.us.txt',
#  'buse.us.txt',
#  'buz.us.txt',
#  'bv.us.txt',
#  'bval.us.txt',
#  'bvn.us.txt',
#  'bvsn.us.txt',
#  'bvx.us.txt',
#  'bvxv.us.txt',
#  'bvxvw.us.txt',
#  'bw.us.txt',
#  'bwa.us.txt',
#  'bwen.us.txt',
#  'bwfg.us.txt',
#  'bwg.us.txt',
#  'bwina.us.txt',
#  'bwinb.us.txt',
#  'bwl-a.us.txt',
#  'bwld.us.txt',
#  'bwp.us.txt',
#  'bwxt.us.txt',
#  'bx.us.txt',
#  'bxc.us.txt',
#  'bxe.us.txt',
#  'bxg.us.txt',
#  'bxmt.us.txt',
#  ...]

# %%
available_tickers = [ticker for ticker in relevant_tickers if f'{ticker.lower()}.us.txt' in os.listdir(data_path)]

# %%
available_tickers
# Out:
# ['BAC',
#  'BCS',
#  'BK',
#  'BX',
#  'CS',
#  'GS',
#  'ING',
#  'JPM',
#  'KKR',
#  'MCO',
#  'MS',
#  'RBS',
#  'RY',
#  'UTX',
#  'WFC',
#  'GM',
#  'HMC',
#  'TM',
#  'AAPL',
#  'AMZN',
#  'BBY',
#  'CSCO',
#  'EBAY',
#  'EC',
#  'GE',
#  'GOOG',
#  'HPQ',
#  'IBM',
#  'INTC',
#  'MA',
#  'MSFT',
#  'NOK',
#  'SNE',
#  'COST',
#  'GPS',
#  'HD',
#  'JCP',
#  'TGT',
#  'WMT',
#  'AIG',
#  'BA',
#  'DAL',
#  'EAD',
#  'FDX',
#  'UAL',
#  'UPS',
#  'BP',
#  'CAT',
#  'CVX',
#  'ISM',
#  'JNJ',
#  'KO',
#  'MCD',
#  'PEP',
#  'PFE',
#  'PG',
#  'SBUX',
#  'XOM',
#  'AA',
#  'BMO',
#  'RIO',
#  'VOD',
#  'VZ']

# %%
len(available_tickers)
# Out:
# 63

# %%
import pandas as pd

# %%
pd.read_csv(os.path.join(data_path, f'{"BAC".lower()}.us.txt'))
# Out:
#             Date     Open     High      Low    Close    Volume  OpenInt
# 0     1986-05-29   3.6107   3.6389   3.6107   3.6295  16691365        0
# 1     1986-05-30   3.6107   3.6578   3.6107   3.6578   6895475        0
# 2     1986-06-02   3.6578   3.6768   3.6295   3.6485    333487        0
# 3     1986-06-03   3.6389   3.6768   3.6295   3.6768    163776        0
# 4     1986-06-04   3.6485   3.6768   3.6204   3.6204    203654        0
# ...          ...      ...      ...      ...      ...       ...      ...
# 7924  2017-11-06  27.7400  27.8199  27.6200  27.7500  37218462        0
# 7925  2017-11-07  27.7400  27.7700  27.0200  27.1800  68282386        0
# 7926  2017-11-08  26.9600  26.9600  26.4900  26.7900  82995186        0
# 7927  2017-11-09  26.4900  26.6600  26.1200  26.4900  95371790        0
# 7928  2017-11-10  26.5900  26.7400  26.4600  26.5100  61095242        0
#
# [7929 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
import os
from scipy.signal import savgol_filter

# %%
def get_log_close_values(ticker_name, start_date='2015-10-20', end_date='2017-11-20', window_length=11, polyorder=3):
    # Load the data into a DataFrame
    df = pd.read_csv(os.path.join(data_path, f'{ticker_name.lower()}.us.txt'))

    # Convert the 'Date' column to datetime format
    df['Date'] = pd.to_datetime(df['Date'])

    # Convert input dates to datetime format
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    # Filter rows between start_date and end_date
    mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
    filtered_df = df.loc[mask]

    # Calculate the natural log of 'Close' values as a numpy array
    log_close_values = np.log(filtered_df['Close'].values)

    # Apply Savitzky-Golay filtering to the log values
    smoothed_values = savgol_filter(log_close_values, window_length, polyorder)

    return smoothed_values

# %%
def plot_smoothed_vs_unsmoothed(ticker_name, start_date='2015-10-20', end_date='2017-11-20', window_length=11, polyorder=3):
    # Load the data into a DataFrame
    df = pd.read_csv(os.path.join(data_path, f'{ticker_name.lower()}.us.txt'))

    # Convert the 'Date' column to datetime format
    df['Date'] = pd.to_datetime(df['Date'])

    # Convert input dates to datetime format
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    # Filter rows between start_date and end_date
    mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
    filtered_df = df.loc[mask]

    # Calculate the natural log of 'Close' values as a numpy array
    log_close_values = np.log(filtered_df['Close'].values)

    # Apply Savitzky-Golay filtering to the log values
    smoothed_values = savgol_filter(log_close_values, window_length, polyorder)

    # Plot the smoothed vs. unsmoothed data
    plt.figure(figsize=(12, 6))
    plt.plot(filtered_df['Date'], log_close_values, label='Unsmoothed', color='blue')
    plt.plot(filtered_df['Date'], smoothed_values, label='Smoothed', color='red')
    plt.title(f'{ticker_name} Log Close Values')
    plt.xlabel('Date')
    plt.ylabel('Log Close Value')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function to plot the data
plot_smoothed_vs_unsmoothed('GOOGL', start_date='2015-10-20', end_date='2017-11-20', window_length=11, polyorder=3)

# %%
available_tickers_idx = {available_tickers[i]:i for i in range(len(available_tickers))}

# %%
def create_graph(available_tickers):
    # Initialize an empty adjacency matrix
    adjacency_matrix = np.zeros((len(available_tickers), len(available_tickers)))

    # Calculate the DDTW distance for each pair of tickers
    for i in range(len(available_tickers)):
        for j in range(i+1, len(available_tickers)):
            seq1 = get_log_close_values(available_tickers[i])
            seq2 = get_log_close_values(available_tickers[j])
            ddtw_distance = fast_ddtw(seq1, seq2, K = 500)[0]
            print(ddtw_distance)
            adjacency_matrix[i][j] = ddtw_distance
            adjacency_matrix[j][i] = ddtw_distance  # because DDTW is a symmetric measure
    
    print(adjacency_matrix)

    # Create a graph from the adjacency matrix
    G = nx.from_numpy_matrix(adjacency_matrix)

    # Label nodes with the correct ticker names
    label_mapping = {i: ticker for i, ticker in enumerate(available_tickers)}
    G = nx.relabel_nodes(G, label_mapping)

    # Set edge weights
    for i, j in G.edges():
        G[i][j]['weight'] = adjacency_matrix[available_tickers_idx[i]][available_tickers_idx[j]]

    return adjacency_matrix, G

# %%
import networkx as nx

# %%
adjacency_matrix, distance_graph = create_graph(available_tickers)
# Out:
# 1.9883257360310962
# 1.3458710615298786
# 1.6734423119434712
# 1.885019035524469
# 1.102997838538391
# 1.682647089516063
# 1.064593439524132
# 1.7711184509812625
# 1.6291402608131946
# 0.9376670047521966
# 0.7891096090580058
# 0.5215066141932808
# 0.8941164598486817
# 0.7208028936561749
# 1.0667245938591323
# 0.8869543359021013
# 3.8499144354844805
# 1.0684445567319987
# 2.849760485445794
# 1.0625222843806954
# 1.002007143462147
# 0.7819955918950718
# 1.1236807622934797
# 0.8673048262222285
# 1.077506674342548
# 1.0152533775481531
# 3.549974544770425
# 1.1073119304672823
# 2.6317090608520353
# 1.033112982746468
# 0.9990128087426101
# 0.9277866835053739
# 0.652138220103478
# 1.0498487079771537
# 0.8784798995328116
# 3.8892053047084225
# 1.0912397940993173
# 2.807680077641926
# 1.0144294795639266
# 0.9763200071443023
# 1.004211632247662
# 1.2316478965095619
# 0.9941366638603581
# 3.3900519151067248
# 1.1802733437592265
# 2.5865651399618845
# 1.1159568657462784
# 1.1498405439349897
# 1.1167475044176924
# 0.9154594324522383
# 3.867127800885334
# 1.0863018345763085
# 2.80902471756146
# 1.1085791399252578
# 1.030603693138237
# 1.1124285860162888
# 3.178659800855744
# 1.078149452317523
# 2.325590172603432
# 1.0529227298333321
# 1.2796316973381987
# 3.4868801554622686
# 0.9702401363214781
# 2.5506466889820723
# 1.044147611561919
# 1.136704382460658
# 3.1059018456805956
# 2.391668999407317
# 3.071255616027753
# 3.4775651500807636
# 2.314552041949608
# 1.1096662007654998
# 1.1836893342719792
# 2.3777463830451904
# 2.5750714864917272
# 1.2345490483021087
# [[0.         1.98832574 1.34587106 ... 1.91475027 1.67320287 1.87465653]
#  [1.98832574 0.         2.02332372 ... 2.25616622 2.30222018 2.54826786]
#  [1.34587106 2.02332372 0.         ... 2.21533138 1.1615541  1.31192713]
#  ...
#  [1.91475027 2.25616622 2.21533138 ... 0.         2.37774638 2.57507149]
#  [1.67320287 2.30222018 1.1615541  ... 2.37774638 0.         1.23454905]
#  [1.87465653 2.54826786 1.31192713 ... 2.57507149 1.23454905 0.        ]]

# %%
adjacency_matrix
# Out:
# array([[0.        , 1.98832574, 1.34587106, ..., 1.91475027, 1.67320287,
#         1.87465653],
#        [1.98832574, 0.        , 2.02332372, ..., 2.25616622, 2.30222018,
#         2.54826786],
#        [1.34587106, 2.02332372, 0.        , ..., 2.21533138, 1.1615541 ,
#         1.31192713],
#        ...,
#        [1.91475027, 2.25616622, 2.21533138, ..., 0.        , 2.37774638,
#         2.57507149],
#        [1.67320287, 2.30222018, 1.1615541 , ..., 2.37774638, 0.        ,
#         1.23454905],
#        [1.87465653, 2.54826786, 1.31192713, ..., 2.57507149, 1.23454905,
#         0.        ]])

# %%
distance_graph

# %%
import networkx as nx
import community as community_louvain
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans


def process_graph(G):
    
    kmeans = KMeans(n_clusters=9, random_state=0).fit(adjacency_matrix)


    labels = kmeans.labels_

    # Create a color map for the clusters
    cmap = plt.cm.get_cmap('viridis', max(labels) + 1)

    # Generate a layout using spring_layout
    pos = nx.spring_layout(G, k =0.6)

    # Draw the graph using the layout and color the nodes by cluster
    nx.draw_networkx_nodes(G, pos=pos, node_color=[cmap(label) for label in labels])
    nx.draw_networkx_edges(G, pos=pos)
    plt.show()

# %%
import plotly.graph_objects as go

import networkx as nx

# %%
G = distance_graph

def remove_edges_above_75_percentile(G):
    G_copy = G.copy()
    for node in G_copy.nodes:
        edges = G_copy .edges(node, data=True)
        if len(edges) > 0:
            weights = np.array([edge[2]['weight'] for edge in edges])
            threshold = np.percentile(weights, 75)
            for edge in edges:
                if edge[2]['weight'] >= threshold and edge in G:
                    G.remove_edge(edge[0], edge[1])
    return G

# %%
G = G_original

# %%
G = remove_edges_above_75_percentile(G)

# %%
edge_x = []
edge_y = []

pos = nx.spring_layout(G)

for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node, pos in pos.items():
    x, y = pos
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# %%
import networkx as nx
import plotly.graph_objs as go
import plotly.offline as pyo

# %%
layout = go.Layout(
    showlegend=False,
    hovermode='closest',
    title="Your Network Graph Title"
)

# Add edge_trace and node_trace to the data list
data = [edge_trace, node_trace]

# Create the figure
fig = go.Figure(data=data, layout=layout)

# Display the graph (in a Jupyter Notebook) or save it to an HTML file
pyo.iplot(fig)
# Out:
# <div>                            <div id="dd4bb62a-611c-4615-afd2-8cea173c1ffd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd4bb62a-611c-4615-afd2-8cea173c1ffd")) {                    Plotly.newPlot(                        "dd4bb62a-611c-4615-afd2-8cea173c1ffd",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[0.7297345326486055,0.3746667433188816,null,0.7297345326486055,-0.22580284468282857,null,0.7297345326486055,0.32355875874941337,null,0.7297345326486055,0.10915532345411172,null,0.7297345326486055,-0.7955312664899313,null,0.7297345326486055,-0.5704559345776883,null,0.7297345326486055,0.1228706254780885,null,0.7297345326486055,0.402284444411578,null,0.7297345326486055,0.6742652483115633,null,0.7297345326486055,0.5013445149970093,null,0.7297345326486055,-0.07699806298935338,null,0.7297345326486055,-0.5864259367116534,null,0.7297345326486055,-0.7290169146266708,null,0.7297345326486055,-0.029015838257199694,null,0.7297345326486055,0.02524028436630201,null,0.7297345326486055,-0.16962524047543825,null,0.7297345326486055,0.6575808421661907,null,0.7297345326486055,-0.38685657955208347,null,0.7297345326486055,-0.4738342361373412,null,0.7297345326486055,0.2095729920829481,null,0.7297345326486055,-0.5234813547879975,null,0.7297345326486055,-0.2960192573023415,null,0.7297345326486055,0.01034938749929716,null,0.7297345326486055,-0.384612251431139,null,0.7297345326486055,-0.4388697608317454,null,0.7297345326486055,0.08548352757735968,null,0.7297345326486055,-0.060950251658934036,null,0.7297345326486055,0.821496455538792,null,0.7297345326486055,0.5378113747461655,null,0.7297345326486055,-0.9061771031490065,null,0.7297345326486055,-0.3473488711137148,null,0.7297345326486055,0.36788050329020705,null,0.7297345326486055,-0.6194475420855002,null,0.7297345326486055,0.03871410934645201,null,0.7297345326486055,-0.8710933793192137,null,0.7297345326486055,-0.07152878933808399,null,0.7297345326486055,0.4293393667369577,null,0.7297345326486055,0.7395059686285881,null,0.7297345326486055,0.4027429980690957,null,0.7297345326486055,-0.8482223061464893,null,0.7297345326486055,0.6060495129948605,null,0.7297345326486055,0.27492945139266245,null,0.7297345326486055,0.7351728698938818,null,0.7297345326486055,-0.416046727722431,null,0.7297345326486055,-0.14863384760594345,null,0.7297345326486055,-0.1355491789229849,null,0.7297345326486055,0.8011754894651181,null,0.7297345326486055,0.8599890169434615,null,0.7297345326486055,0.286164368871986,null,0.7297345326486055,-0.8374542005425232,null,0.7297345326486055,-0.3118550905412255,null,0.7297345326486055,0.40342567374142513,null,0.7297345326486055,0.14147904838799372,null,0.7297345326486055,0.18359982701384364,null,0.7297345326486055,-0.5963427822764459,null,0.7297345326486055,1.0,null,0.7297345326486055,-0.6799553875972361,null,0.7297345326486055,-0.1682714476495287,null,0.7297345326486055,-0.7671319627166081,null,0.7297345326486055,-0.2888518241243884,null,0.7297345326486055,0.6888975750280187,null,0.7297345326486055,0.2169253362128577,null,0.3746667433188816,-0.22580284468282857,null,0.3746667433188816,0.32355875874941337,null,0.3746667433188816,0.10915532345411172,null,0.3746667433188816,-0.7955312664899313,null,0.3746667433188816,-0.5704559345776883,null,0.3746667433188816,0.1228706254780885,null,0.3746667433188816,0.402284444411578,null,0.3746667433188816,0.6742652483115633,null,0.3746667433188816,0.5013445149970093,null,0.3746667433188816,-0.07699806298935338,null,0.3746667433188816,-0.5864259367116534,null,0.3746667433188816,-0.7290169146266708,null,0.3746667433188816,-0.029015838257199694,null,0.3746667433188816,0.02524028436630201,null,0.3746667433188816,-0.16962524047543825,null,0.3746667433188816,0.65758084216619 ...

# %%
pos = nx.spring_layout(G)

# Extract node positions into a list
node_positions = [pos[node] for node in G.nodes()]

# Number of clusters you want to create
num_clusters = 6  # You can change this to the desired number of clusters

# Apply K-Means clustering to the node positions
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
node_clusters = kmeans.fit_predict(node_positions)

# Create a colormap for coloring nodes based on their cluster
colormap = ['red', 'blue', 'green', 'purple', 'orange', 'pink', 'cyan']

# Create a list to store node colors based on their cluster
node_colors = [colormap[cluster] for cluster in node_clusters]

# Rest of the code for generating edge_trace

# Create a scatter trace for nodes with colors based on their cluster
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        color=node_colors,  # Use the cluster colors
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Clusters',  # You can change the title
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# Create the layout as shown in the previous response

# Add edge_trace and modified node_trace to the data list
data = [edge_trace, node_trace]

# Create the figure and display or save the graph
fig = go.Figure(data=data, layout=layout)

# Display the graph (in a Jupyter Notebook) or save it to an HTML file
pyo.iplot(fig)
# Out:
# <div>                            <div id="6517b927-0ade-48f5-b3af-1113170ca0bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6517b927-0ade-48f5-b3af-1113170ca0bb")) {                    Plotly.newPlot(                        "6517b927-0ade-48f5-b3af-1113170ca0bb",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[0.7297345326486055,0.3746667433188816,null,0.7297345326486055,-0.22580284468282857,null,0.7297345326486055,0.32355875874941337,null,0.7297345326486055,0.10915532345411172,null,0.7297345326486055,-0.7955312664899313,null,0.7297345326486055,-0.5704559345776883,null,0.7297345326486055,0.1228706254780885,null,0.7297345326486055,0.402284444411578,null,0.7297345326486055,0.6742652483115633,null,0.7297345326486055,0.5013445149970093,null,0.7297345326486055,-0.07699806298935338,null,0.7297345326486055,-0.5864259367116534,null,0.7297345326486055,-0.7290169146266708,null,0.7297345326486055,-0.029015838257199694,null,0.7297345326486055,0.02524028436630201,null,0.7297345326486055,-0.16962524047543825,null,0.7297345326486055,0.6575808421661907,null,0.7297345326486055,-0.38685657955208347,null,0.7297345326486055,-0.4738342361373412,null,0.7297345326486055,0.2095729920829481,null,0.7297345326486055,-0.5234813547879975,null,0.7297345326486055,-0.2960192573023415,null,0.7297345326486055,0.01034938749929716,null,0.7297345326486055,-0.384612251431139,null,0.7297345326486055,-0.4388697608317454,null,0.7297345326486055,0.08548352757735968,null,0.7297345326486055,-0.060950251658934036,null,0.7297345326486055,0.821496455538792,null,0.7297345326486055,0.5378113747461655,null,0.7297345326486055,-0.9061771031490065,null,0.7297345326486055,-0.3473488711137148,null,0.7297345326486055,0.36788050329020705,null,0.7297345326486055,-0.6194475420855002,null,0.7297345326486055,0.03871410934645201,null,0.7297345326486055,-0.8710933793192137,null,0.7297345326486055,-0.07152878933808399,null,0.7297345326486055,0.4293393667369577,null,0.7297345326486055,0.7395059686285881,null,0.7297345326486055,0.4027429980690957,null,0.7297345326486055,-0.8482223061464893,null,0.7297345326486055,0.6060495129948605,null,0.7297345326486055,0.27492945139266245,null,0.7297345326486055,0.7351728698938818,null,0.7297345326486055,-0.416046727722431,null,0.7297345326486055,-0.14863384760594345,null,0.7297345326486055,-0.1355491789229849,null,0.7297345326486055,0.8011754894651181,null,0.7297345326486055,0.8599890169434615,null,0.7297345326486055,0.286164368871986,null,0.7297345326486055,-0.8374542005425232,null,0.7297345326486055,-0.3118550905412255,null,0.7297345326486055,0.40342567374142513,null,0.7297345326486055,0.14147904838799372,null,0.7297345326486055,0.18359982701384364,null,0.7297345326486055,-0.5963427822764459,null,0.7297345326486055,1.0,null,0.7297345326486055,-0.6799553875972361,null,0.7297345326486055,-0.1682714476495287,null,0.7297345326486055,-0.7671319627166081,null,0.7297345326486055,-0.2888518241243884,null,0.7297345326486055,0.6888975750280187,null,0.7297345326486055,0.2169253362128577,null,0.3746667433188816,-0.22580284468282857,null,0.3746667433188816,0.32355875874941337,null,0.3746667433188816,0.10915532345411172,null,0.3746667433188816,-0.7955312664899313,null,0.3746667433188816,-0.5704559345776883,null,0.3746667433188816,0.1228706254780885,null,0.3746667433188816,0.402284444411578,null,0.3746667433188816,0.6742652483115633,null,0.3746667433188816,0.5013445149970093,null,0.3746667433188816,-0.07699806298935338,null,0.3746667433188816,-0.5864259367116534,null,0.3746667433188816,-0.7290169146266708,null,0.3746667433188816,-0.029015838257199694,null,0.3746667433188816,0.02524028436630201,null,0.3746667433188816,-0.16962524047543825,null,0.3746667433188816,0.65758084216619 ...

# %%
node_labels = available_tickers

# Create a scatter trace for nodes with labels
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers+text',  # Use 'markers+text' mode to display labels
    hoverinfo='text',
    text=node_labels,  # Specify the labels for each node
    textposition='top center',  # Adjust text position as needed
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        color=node_colors,  # Use the cluster colors
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Clusters',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# Create the layout as shown in the previous response

# Add edge_trace and modified node_trace to the data list
data = [edge_trace, node_trace]

# Create the figure and display or save the graph
fig = go.Figure(data=data, layout=layout)

# Display the graph (in a Jupyter Notebook) or save it to an HTML file
pyo.iplot(fig)
# Out:
# <div>                            <div id="5cd1dd49-1e31-4f38-a6fb-fb9b877263a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5
# %%
edge_weights = [attr['weight'] for _, _, attr in G.edges(data=True)]

# Calculate the threshold as the 65th percentile (top 35%)
threshold = sorted(edge_weights)[int(0.65 * len(edge_weights))]

# Create a copy of the graph to avoid modifying the original graph
filtered_graph = G.copy()

# Remove edges with weights above the threshold
for u, v, data in G.edges(data=True):
    if data['weight'] > threshold:
        filtered_graph.remove_edge(u, v)

# %%
from sklearn.cluster import SpectralClustering

# %%
import networkx as nx
import plotly.graph_objs as go
import plotly.offline as pyo
import community as community_louvain
import numpy as np

# Define your graph G (you should define or load it before this step)
# G = ...

# Calculate the maximum edge weight in the original graph
max_edge_weight = max(weight for u, v, weight in G.edges(data='weight'))

# Create a new graph with modified edge weights
modified_G = G.copy()
for u, v, data in modified_G.edges(data=True):
    modified_G[u][v]['weight'] = max_edge_weight - data['weight']

# Use python-louvain's best_partition to detect communities
partition = community_louvain.best_partition(modified_G, weight='weight')

# Get the community labels for nodes
node_clusters = [partition[node] for node in modified_G.nodes()]

# Create a colormap for coloring nodes based on their community
colormap = ['red', 'blue', 'green', 'purple', 'orange', 'pink', 'cyan']

# Create a list to store node colors based on their community
node_colors = [colormap[cluster] for cluster in node_clusters]

# Rest of the code for generating edge_trace

# Create a scatter trace for nodes with colors based on their community
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    text=available_tickers,
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        color=node_colors,  # Use the community colors
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Communities',  # You can change the title
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# Create the layout as shown in the previous responses

# Add edge_trace and modified node_trace to the data list
data = [edge_trace, node_trace]

# Create the figure and display or save the graph
fig = go.Figure(data=data, layout=layout)

# Display the graph (in a Jupyter Notebook) or save it to an HTML file
pyo.iplot(fig)  # Display in Jupyter Notebook
# OR
# pyo.plot(fig, filename='louvain_clustered_graph.html')  # Save to an HTML file
# Out:
# <div>                            <div id="45589c3c-e95b-4ca9-a937-8187dd2c5315" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45589c3c-e95b-4ca9-a937-8187dd2c5315")) {                    Plotly.newPlot(                        "45589c3c-e95b-4ca9-a937-8187dd2c5315",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[0.2094309464970307,-0.1311473987868266,null,0.2094309464970307,-0.31835354256214,null,0.2094309464970307,-0.46892624698205104,null,0.2094309464970307,0.031042796636266426,null,0.2094309464970307,-0.652424005849994,null,0.2094309464970307,0.33246757275975775,null,0.2094309464970307,-0.41876999428991846,null,0.2094309464970307,-0.406330107784558,null,0.2094309464970307,0.638798288208096,null,0.2094309464970307,0.26585186933080385,null,0.2094309464970307,0.28809954475609945,null,0.2094309464970307,0.7195969201108972,null,0.2094309464970307,1.0,null,0.2094309464970307,0.8582492775117794,null,0.2094309464970307,-0.7256630922837649,null,0.2094309464970307,0.7254511372934535,null,0.2094309464970307,-0.3557837049808532,null,0.2094309464970307,0.6036390275360188,null,0.2094309464970307,-0.35670127183108336,null,0.2094309464970307,0.20478107973107015,null,0.2094309464970307,0.8758495994505776,null,0
# 1 ;  ['BAC', 'BCS', 'BX', 'CS', 'GS', 'ING', 'KKR', 'MS', 'RBS', 'WFC', 'GM', 'AMZN', 'BBY', 'EBAY', 'EC', 'HPQ', 'NOK', 'SNE', 'GPS', 'JCP', 'TGT', 'DAL', 'UAL', 'BP', 'CAT', 'AA', 'RIO']
# ==============================
# 2 ;  []
# ==============================
# 3 ;  []
# ==============================
# 4 ;  []
# ==============================
# 5 ;  []
# ==============================
# 6 ;  []
# ==============================

# %%
start_date = '2015-10-20'
end_date='2017-11-20'

for cluster_id, tickers in clusters.items():
    if not tickers:
        continue

    plt.figure(figsize=(12, 6))
    plt.title(f'Cluster {cluster_id} Data')
    plt.xlabel('Time')
    plt.ylabel('Value')

    for ticker_name in tickers:
        df_ticker = pd.read_csv(os.path.join(data_path, f'{ticker_name.lower()}.us.txt'))

        # Convert the 'Date' column to datetime format
        df_ticker['Date'] = pd.to_datetime(df_ticker['Date'])

        # Convert input dates to datetime format
        start_date_dt = pd.to_datetime(start_date)
        end_date_dt = pd.to_datetime(end_date)

        # Filter rows between start_date and end_date
        mask = (df_ticker['Date'] >= start_date_dt) & (df_ticker['Date'] <= end_date_dt)
        filtered_df_ticker = df_ticker.loc[mask]

        # Calculate the natural log of 'Close' values as a numpy array
        log_close_values = np.log(filtered_df_ticker['Close'].values)

        # Apply Savitzky-Golay filtering to the log values
        smoothed_values = savgol_filter(log_close_values, 11, 3)

        # Plot the smoothed vs. unsmoothed data
        plt.plot(filtered_df_ticker['Date'], log_close_values, label=f'{ticker_name} (Unsmoothed)', alpha=0.6, linestyle='--')
        plt.plot(filtered_df_ticker['Date'], smoothed_values, label=f'{ticker_name} (Smoothed)')

    plt.legend()
    plt.grid(True)
    plt.show()

# %%
adj_matrix = nx.adjacency_matrix(distance_graph)

# %%
adj_matrix.toarray()
# Out:
# array([[0.        , 1.98832574, 1.34587106, ..., 1.91475027, 1.67320287,
#         1.87465653],
#        [1.98832574, 0.        , 2.02332372, ..., 2.25616622, 2.30222018,
#         2.54826786],
#        [1.34587106, 2.02332372, 0.        , ..., 2.21533138, 1.1615541 ,
#         1.31192713],
#        ...,
#        [1.91475027, 2.25616622, 2.21533138, ..., 0.        , 2.37774638,
#         2.57507149],
#        [1.67320287, 2.30222018, 1.1615541 , ..., 2.37774638, 0.        ,
#         1.23454905],
#        [1.87465653, 2.54826786, 1.31192713, ..., 2.57507149, 1.23454905,
#         0.        ]])

# %%
partition = community_louvain.best_partition(distance_graph)

clusters = {}
for node, cluster_id in partition.items():
    if cluster_id not in clusters:
        clusters[cluster_id] = []
    clusters[cluster_id].append(node)

# Print the clusters and nodes
for cluster_id, nodes in clusters.items():
    print(f"Cluster {cluster_id}: {nodes}")
# Out:
# Cluster 0: ['BAC', 'BCS', 'BK', 'BX', 'CS', 'GS', 'ING', 'JPM', 'KKR', 'MCO', 'MS', 'RBS', 'RY', 'UTX', 'WFC', 'GM', 'HMC', 'TM', 'AAPL', 'AMZN', 'BBY', 'CSCO', 'EBAY', 'EC', 'GE', 'GOOG', 'HPQ', 'IBM', 'INTC', 'MA', 'MSFT', 'NOK', 'SNE', 'COST', 'GPS', 'HD', 'JCP', 'TGT', 'WMT', 'AIG', 'BA', 'DAL', 'EAD', 'FDX', 'UAL', 'UPS', 'BP', 'CAT', 'CVX', 'ISM', 'JNJ', 'KO', 'MCD', 'PEP', 'PFE', 'PG', 'SBUX', 'XOM', 'AA', 'BMO', 'RIO', 'VOD', 'VZ']

# %%
kmeans = KMeans(n_clusters=7, random_state=3).fit(adjacency_matrix)

# %%
labels = kmeans.labels_

# %%
n = 7

kmeans = KMeans(n_clusters=n, random_state=0).fit(adjacency_matrix)

labels = kmeans.labels_

clusters = {i: [] for i in range(n)}

for tick, label in zip(available_tickers, labels):
    clusters[label].append(tick)

for cluster, ticks in clusters.items():
    print(cluster, '; ', ticks)
    print('='*30)
# Out:
# 0 ;  ['UTX', 'GE', 'MA', 'COST', 'HD', 'WMT', 'EAD', 'UPS', 'ISM', 'JNJ', 'KO', 'MCD', 'PEP', 'PFE', 'PG', 'XOM', 'VZ']
# ==============================
# 1 ;  ['GPS', 'AA']
# ==============================
# 2 ;  ['BX', 'KKR', 'BBY', 'NOK']
# ==============================
# 3 ;  ['JCP']
# ==============================
# 4 ;  ['BK', 'GS', 'JPM', 'MCO', 'RY', 'WFC', 'GM', 'HMC', 'TM', 'AAPL', 'CSCO', 'GOOG', 'IBM', 'INTC', 'MSFT', 'AIG', 'BA', 'FDX', 'BP', 'CVX', 'SBUX', 'BMO', 'VOD']
# ==============================
# 5 ;  ['BCS', 'CS', 'RBS', 'EC', 'UAL', 'RIO']
# ==============================
# 6 ;  ['BAC', 'ING', 'MS', 'AMZN', 'EBAY', 'HPQ', 'SNE', 'TGT', 'DAL', 'CAT']
# ==============================

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import numpy as np

def optimal_k_silhouette(adj_matrix):
    silhouette_scores = []
    K = range(2, 10) # change this range according to your needs

    for k in K:
        kmeans = KMeans(n_clusters=k).fit(adj_matrix)
        labels = kmeans.labels_
        silhouette_scores.append(silhouette_score(adj_matrix, labels, metric='euclidean'))
    
    print(silhouette_scores)
    optimal_k = np.argmax(silhouette_scores) + 2 # +2 because range starts from 2
    return optimal_k

# %%
distance_graph

# %%
optimal_k_silhouette(adjacency_matrix)
# Out:
# [0.6144360221801567, 0.5616888432590079, 0.3587150815196653, 0.33798735777413386, 0.21545088493510672, 0.20823740052600437, 0.17518102810195404, 0.1685011047149879]
# 2

# %%
from sklearn.cluster import KMeans

def inter_intra_cluster_variance(adj_matrix, n_clusters):
    kmeans = KMeans(n_clusters=n_clusters).fit(adj_matrix)
    labels = kmeans.labels_
    
    inter_cluster_variance = kmeans.inertia_
    
    intra_cluster_variance = 0
    for i in range(n_clusters):
        cluster_points = adj_matrix[labels == i]
        cluster_mean = cluster_points.mean(axis=0)
        intra_cluster_variance += ((cluster_points - cluster_mean)**2).sum()
    
    return inter_cluster_variance, intra_cluster_variance

# %%
inter_intra_cluster_variance(adjacency_matrix, 2)
# Out:
# (675.2405110398887, 675.2405110398889)

# %%
inter_intra_cluster_variance(adjacency_matrix, 6)
# Out:
# (215.39310271402678, 215.39310271402675)
